# %% [markdown]
# # Some features

# %% [markdown]
# Use # to make the heading with big font size

# %% [markdown]
# Use ## to make the heading with slightly lower size

# %% [markdown]
# Press A to create a cell after active cell

# %% [markdown]
# Press B to create a cell before active cell

# %% [markdown]
# Double Press D to delete active cell

# %% [markdown]
# # Sequence data type

# %% [markdown]
# Sequence data type
#
# 1. Sequences allow you to store multiple values in an organized and efficient fashion
# 2. There are several sequence types: strings, Unicode strings, lists, tuples, arrays and range objects
# 3. Dictionaries and sets are containers for non-sequential data
#
# • Strings – Sequence of characters – " (or) '
#
# • Tuples – Sequence of compound data – ()
#
# • Lists – Sequence of multi-data type objects – []
#
# • Arrays – Sequence of constrained list of objects (all objects of same datatype) using array module from array package
#
# • Dictionary – Sequence of key-value pairs – {}
#
# • Sets – Sequence of unordered collection of unique data
#
# • Range – Used for looping – using built-in range()
#
#
# These can offer unique functionalities for the variables to contain and handle more than one data datatype at a time. Supports operations such as indexing, slicing, concatenation, multiplication etc.

# %% [markdown]
# # STRING

# %%
string="raj" #string are immutable
print (string)
# Out:
# raj

# %% [markdown]
# # LIST

# %%
listA=[1,2,2,2,3,5,8]   #list are mutable, data can be dublicate
print (listA)
# Out:
# [1, 2, 2, 2, 3, 5, 8]

# %%
listB=[1,'raj',2.8]    #List can contain various data type together
print (listB)
# Out:
# [1, 'raj', 2.8]

# %% [markdown]
# # ARRAY

# %%
from array import *    #Importing array module

# %%
arrayA=array('i',[1,2,3,3,5,9,7])         #Array function (First argument as data type and second argument as data in form of list
#This is a example of one dimentional array

# %%
for x in arrayA: print (x)          #Printing the values of array
# Out:
# 1
# 2
# 3
# 3
# 5
# 9
# 7

# %%
print (arrayA)
# Out:
# array('i', [1, 2, 3, 3, 5, 9, 7])

# %% [markdown]
# # TUPLE

# %% [markdown]
# It is same as list but the difference is that we cann't change the elements of Tuplel (unlike list) once the values are assigned

# %%
tupleA=(1,2,'ram',1.55)           #Tuple
print (tupleA)
# Out:
# (1, 2, 'ram', 1.55)

# %%
tupleB=1,2,'raj',2.55           #Tuple Packing, We can also create tuple without round bracket called tuple packing
print (tupleA)
# Out:
# (1, 2, 'ram', 1.55)

# %% [markdown]
# # DICTIONARY

# %% [markdown]
# # SETS

# %%
setA={1,2.5,"p"}    #Unordered data type, It can contain any immutable data type i.e. list cann't be an element of Set
#set cann't be an element of set
print (type(setA))
# Out:
# <class 'set'>

# %%
# Set function (in built)
# used to create the set by taking List, Tuple, String as parameter and it will form list consisting of the elemets of the parameter

setA=set("Russia")

# %%
for x in setA:print(x)
# Out:
# p
# 2.5
# 1

# %% [markdown]
# # RANGE

# %% [markdown]
# ##### Range is a sequence data type inbuilt in python
# ##### Commanly used for looping

# %%
# Range function take three argument
rangeA=range(1,21,4) 
#First one is Start value
#Second one is Last value (end output will couned as n-1 value)
#Third one is Stop value i.e. before which function have to return the value ( STEP SIZE)

# %%
for x in rangeA: print (x)
# Out:
# 1
# 5
# 9
# 13
# 17
